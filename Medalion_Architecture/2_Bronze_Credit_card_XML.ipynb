# %%
lines = []
with open("/Volumes/customer_360/source_data/raw/Credit_Card/creditcard.xml", "r", encoding="utf-8", errors="replace") as f:
    for i, line in enumerate(f):
        if i >= 100:
            break
        lines.append(line)

print("".join(lines))
